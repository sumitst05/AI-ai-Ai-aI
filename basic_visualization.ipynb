# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
x = np.array([1,2,3,4,5])
y = np.array([34,56,87,13,23])

# %%
plt.pie(y,labels = x)
plt.show()

# %%
img = np.array([
    [
        [1,0,0],
        [1,0,1],
        [1,1,1]
                  ],   #First image
    [
        [0,1,0],
        [1,1,1],
        [0,1,0]
                  ]     #second image
])

print(img[0].shape)
# Out:
# (3, 3)

# %%
plt.matshow(img)

# %%
img = []
dimension = 100
for j in range(dimension):
  row = []
  for i in range(dimension):
    # row.append(random.randint(1,10))

    # if i<=j:
    #   row.append(1)
    # else:
    #   row.append(0)

    row.append(i+j)
  img.append(row)

img = np.array(img)
print(img)
# Out:
# [[  0   1   2 ...  97  98  99]
#  [  1   2   3 ...  98  99 100]
#  [  2   3   4 ...  99 100 101]
#  ...
#  [ 97  98  99 ... 194 195 196]
#  [ 98  99 100 ... 195 196 197]
#  [ 99 100 101 ... 196 197 198]]

# %%
plt.matshow(img)
